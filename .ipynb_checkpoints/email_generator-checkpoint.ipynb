# %% [markdown]
# Cool Email generator

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("Do you like cats or dogs?")
print(response.content)
# Out:
# I don't have personal preferences, including liking or disliking cats or dogs. I am a machine designed to provide information and assist with tasks, but I don't have personal feelings or emotions. However, I can provide information and answer questions about both cats and dogs if you're interested!

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://brainstation-23.com/healthcare/")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
#   Industry (Healthcare) | Brain Station 23 PLC. | Professionals @ Your Service                                           Skip to content  HomeServicesMenu ToggleField Force AutomationAdobe Experience ManagerBanking SolutionMobile App DevelopmentAR-VR SolutionMenu ToggleAugmented RealityVirtual Reality3D ModelingGame StudioCloud & Cyber SecurityERPE-commerce SolutionSharePoint ServicesData Science & Business IntelligenceML & AISoftware Testing as ServiceIndustriesMenu ToggleFintechHealthcareTelecomReal EstateSoftware/ITESe-CommerceEducationRetailAutomotiveStartupCase StudiesBlogAbout UsMenu ToggleAbout UsMediaOur PartnersCareerInvestorsContact Us     Main Menu    HomeServicesMenu ToggleField Force AutomationAdobe Experience ManagerBanking SolutionMobile App DevelopmentAR-VR SolutionMenu ToggleAugmented RealityVirtual Reality3D ModelingGame StudioCloud & Cyber SecurityERPE-commerce SolutionSharePoint ServicesData Science & Business IntelligenceML & AISoftware Testing as ServiceIndustriesMenu ToggleFintechHealthcareTelecomReal EstateSoftware/ITESe-CommerceEducationRetailAutomotiveStartupCase StudiesBlogAbout UsMenu ToggleAbout UsMediaOur PartnersCareerInvestorsContact UsHealthcare ServicesWe serve healthcare and pharmaceuticals with the latest technological innovations to help meet the ever-increasing industry demands. We deliver regulation compliant solutions for enterprises operating in the healthcare sector to meet the demands of millions of people.      Contact Us     Themes   Users   Active InstallsHow We Can HelpCustom App DevelopmentWe develop custom application solutions that work faithfully according to the need of the regulated healthcare industry.ERP SolutionsOur Odoo powered ERP solutions help enterprises automate their resource management and miscellaneous activities.Cloud SolutionsOur cloud computing services help healthcare enterprises to adopt flexible computing resources and data collection.AR/VR ApplicationsOur AR/VR experts help healthcare enterprises to build engaging solutions to help them facilitate new avenues for research and testing.BI/Analytical ToolsWe help the healthcare industry adopt analytical tools and Business Intelligence solutions to help monitor and strategize business performance effectively.SharePoint SolutionsWe deliver SharePoint services to healthcare organizations to enable the whole organization to collaborate within one platform.SharePoint SolutionsWe deliver SharePoint services to healthcare organizations to enable the whole organization to collaborate within one platform.SharePoint SolutionsWe deliver SharePoint services to healthcare organizations to enable the whole organization to collaborate within one platform.Our Key ExperiencesCase Study 1 Beximco Pharma Service Provided: SharePoint Portal  We installed the updated 2013 version of SharePoint. Regardless of the location of users, the solution was developed for Intranet Portal for the simplification of people’s collaboration, findings, and information sharing for retaining knowledge and for better organizational performance.  View Full Case Study  Case Study 2 AKS Pharmaceutical Service Provided: Full Fledged ERP Solution  We used Odoo (Open source ERP Solution) to develop the ERP solution for them as we have the best developers working on this platform for a long time. We help them to implement HR, POS, Sales, Purchase, Accounts, Inventory , Branch & Requisition Management.  View Full Case Study  Case Study 3 Incepta Pharmaceuticals Service Provided: Mobile Sales Force Automation  Brain Station 23 developed a mobile Sales Force Automation app (mSFA) to create and mobilize sales force for Incepta Pharmaceuticals Limited. Our solution provides Incepta’s MPOs (in operation) with a more effective, automated, and manageable sales force.  View Full Case Study  Case Study 4 Aristo Pharma Ltd. Service Provided: Mobile Sales Force Automation Apps  We developed an advanced mSFA for Aristopharma. So now the MPOs can take orders, check real ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Front-End Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Full-Stack Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Angular Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Node.js Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'JavaScript Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'React Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': '.NET Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Java Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'PHP Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Python Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'C/C++ Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'C# Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Ruby Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Unity3D Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'iOS Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Android Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'nopCommerce Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Drupal Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'SQL Developers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'QA Engineers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'UI/UX Designers',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Product Owner',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Scrum Master',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'DevOps Engineer',
#   'experience': None,
#   'skills': None,
#   'description': None}]

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import uuid
# ----> 2 import chromadb
#       4 client = chromadb.PersistentClient('vectorstore')
#       5 collection = client.get_or_create_collection(name="portfolio")
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
print(res.content)
# Out:
# ```json
# [
#   {
#     "role": "Front-End Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Full-Stack Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Angular Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Node.js Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "JavaScript Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "React Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": ".NET Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Java Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "PHP Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Python Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "C/C++ Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "C# Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Ruby Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Unity3D Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "iOS Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Android Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "nopCommerce Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Drupal Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "SQL Developers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "QA Engineers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "UI/UX Designers",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Product Owner",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "Scrum Master",
#     "experience": null,
#     "skills": null,
#     "description": null
#   },
#   {
#     "role": "DevOps Engineer",
#     "experience": null,
#     "skills": null,
#     "description": null
#   }
# ]
# ```

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
